# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 95% !important; }</style>"))
# Out:
# <style>.container { width: 95% !important; }</style>

# %%
import pandas

# %%
with open('./data_genome_architecture.txt', 'r') as infile:
    data = pandas.read_csv(infile, delimiter = '\t')
# data

# %%
c = list(zip(list(data.SOURCE), list(data.TARGET)))
c = [elt for sublist in c for elt in sublist]

architecture = list(dict.fromkeys(c).keys())
# architecture

# %%
for dna_part in architecture:
    Rule = ''

    if 'pro' in dna_part: # docking rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'docking_{:s}\',\n'\
               '    cplx(name = \'RNAP\', dna = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\') |\n' \
               '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\'),\n' \
               '    Parameter(\'fwd_docking_{:s}\', 0), Parameter(\'rvs_docking_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
        
    elif 'ter' in dna_part: # falloff rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'falloff_{:s}\',\n'\
               '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') >>\n' \
               '    cplx(name = \'RNAP\', dna = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\'),\n' \
               '    Parameter(\'fwd_falloff_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('docking_fucP_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucP', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fucP_pro1', 0), Parameter('rvs_docking_fucP_pro1', 0))
#
# Rule('docking_fucU_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucU', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fucU_pro1', 0), Parameter('rvs_docking_fucU_pro1', 0))
#
# Rule('docking_fucR_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucR', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fucR_pro1', 0), Parameter('rvs_docking_fucR_pro1', 0))
#
# Rule('falloff_fucR_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucR', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_fucR_ter1', 0))
#
# Rule('docking_fucA_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucA', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fucA_pro1', 0), Parameter('rvs_docking_fucA_pro1', 0))
#
# Rule('docking_fucO_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucO', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fucO_pro1', 0), Parameter('rvs_docking_fucO_pro1', 0))
#
# Rule('falloff_fucO_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fucO', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_fucO_ter1', 0))
#
# Rule('docking_aldA_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'aldA', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_aldA_pro1', 0), Parameter('rvs_docking_aldA_pro1', 0))
#
# Rule('falloff_aldA_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'aldA', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_aldA_ter1', 0))
#
# Rule('docking_lldP_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'lldP', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_lldP_pro1', 0), Parameter('rvs_docking_lldP_pro1', 0))
#
# Rule('falloff_lldD_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'lldD', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_lldD_ter1', 0))

# %%
for dna_part1, dna_part2 in zip(data.SOURCE, data.TARGET):
    name1 = dna_part1.split('-')[0]
    type1 = dna_part1.split('-')[1]
    name2 = dna_part2.split('-')[0]
    type2 = dna_part2.split('-')[1]
    
    if 'BS' in dna_part1:  # catch binding sites to add to sliding rules
        name1 = '_'.join(dna_part1.split('-')[1:])
        type1 = dna_part1.split('-')[1]
    elif 'BS' in dna_part2:
        name2 = '_'.join(dna_part2.split('-')[1:])
        type2 = dna_part2.split('-')[1]
        
    Rule = 'Rule(\'sliding_{:s}\',\n'\
           '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') + None + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\') >>\n' \
           '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') + rna(name = \'{:s}\', type = \'{:s}\', dna = None, prot = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\'),\n' \
           '    Parameter(\'fwd_sliding_{:s}\', 0))' \
           .format(dna_part1, name1, type1, name2, type2, name2, type2, name2, type2, name1, type1, dna_part1)
    
    print(Rule.replace('-', '_'))
    print()
# Out:
# Rule('sliding_fucP_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fucP', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucP', type = 'rbs', dna = None, prot = None) + dna(name = 'fucP', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucP_pro1', 0))
#
# Rule('sliding_fucP_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucP', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucP', type = 'cds', dna = None, prot = None) + dna(name = 'fucP', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucP_rbs', 0))
#
# Rule('sliding_fucP_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucP', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucI', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucI', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucI', type = 'rbs', dna = None, prot = None) + dna(name = 'fucP', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucP_cds', 0))
#
# Rule('sliding_fucI_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucI', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucI', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucI', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucI', type = 'cds', dna = None, prot = None) + dna(name = 'fucI', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucI_rbs', 0))
#
# Rule('sliding_fucI_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucI', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucK', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucK', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucK', type = 'rbs', dna = None, prot = None) + dna(name = 'fucI', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucI_cds', 0))
#
# Rule('sliding_fucK_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucK', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucK', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucK', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucK', type = 'cds', dna = None, prot = None) + dna(name = 'fucK', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucK_rbs', 0))
#
# Rule('sliding_fucK_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucK', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucU', type = 'pro1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'pro1', prot = 1, free = 'False') + rna(name = 'fucU', type = 'pro1', dna = None, prot = None) + dna(name = 'fucK', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucK_cds', 0))
#
# Rule('sliding_fucU_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fucU', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucU', type = 'rbs', dna = None, prot = None) + dna(name = 'fucU', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucU_pro1', 0))
#
# Rule('sliding_fucU_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucU', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucU', type = 'cds', dna = None, prot = None) + dna(name = 'fucU', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucU_rbs', 0))
#
# Rule('sliding_fucU_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucU', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucR', type = 'pro1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'pro1', prot = 1, free = 'False') + rna(name = 'fucR', type = 'pro1', dna = None, prot = None) + dna(name = 'fucU', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucU_cds', 0))
#
# Rule('sliding_fucR_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fucR', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucR', type = 'rbs', dna = None, prot = None) + dna(name = 'fucR', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucR_pro1', 0))
#
# Rule('sliding_fucR_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucR', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucR', type = 'cds', dna = None, prot = None) + dna(name = 'fucR', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucR_rbs', 0))
#
# Rule('sliding_fucR_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucR', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucR', type = 'ter1', prot = 1, free = 'False') + rna(name = 'fucR', type = 'ter1', dna = None, prot = None) + dna(name = 'fucR', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucR_cds', 0))
#
# Rule('sliding_fucA_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fucA', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucA', type = 'rbs', dna = None, prot = None) + dna(name = 'fucA', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucA_pro1', 0))
#
# Rule('sliding_fucA_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucA', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucA', type = 'cds', dna = None, prot = None) + dna(name = 'fucA', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucA_rbs', 0))
#
# Rule('sliding_fucA_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucA', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucO', type = 'pro1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'pro1', prot = 1, free = 'False') + rna(name = 'fucO', type = 'pro1', dna = None, prot = None) + dna(name = 'fucA', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucA_cds', 0))
#
# Rule('sliding_fucO_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fucO', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fucO', type = 'rbs', dna = None, prot = None) + dna(name = 'fucO', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucO_pro1', 0))
#
# Rule('sliding_fucO_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fucO', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'cds', prot = 1, free = 'False') + rna(name = 'fucO', type = 'cds', dna = None, prot = None) + dna(name = 'fucO', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucO_rbs', 0))
#
# Rule('sliding_fucO_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fucO', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fucO', type = 'ter1', prot = 1, free = 'False') + rna(name = 'fucO', type = 'ter1', dna = None, prot = None) + dna(name = 'fucO', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fucO_cds', 0))
#
# Rule('sliding_aldA_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'aldA', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'rbs', prot = 1, free = 'False') + rna(name = 'aldA', type = 'rbs', dna = None, prot = None) + dna(name = 'aldA', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_aldA_pro1', 0))
#
# Rule('sliding_aldA_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'aldA', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'cds', prot = 1, free = 'False') + rna(name = 'aldA', type = 'cds', dna = None, prot = None) + dna(name = 'aldA', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_aldA_rbs', 0))
#
# Rule('sliding_aldA_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'aldA', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'aldA', type = 'ter1', prot = 1, free = 'False') + rna(name = 'aldA', type = 'ter1', dna = None, prot = None) + dna(name = 'aldA', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_aldA_cds', 0))
#
# Rule('sliding_lldP_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'lldP', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'rbs', prot = 1, free = 'False') + rna(name = 'lldP', type = 'rbs', dna = None, prot = None) + dna(name = 'lldP', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldP_pro1', 0))
#
# Rule('sliding_lldP_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'lldP', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'cds', prot = 1, free = 'False') + rna(name = 'lldP', type = 'cds', dna = None, prot = None) + dna(name = 'lldP', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldP_rbs', 0))
#
# Rule('sliding_lldP_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldP', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'lldR', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldR', type = 'rbs', prot = 1, free = 'False') + rna(name = 'lldR', type = 'rbs', dna = None, prot = None) + dna(name = 'lldP', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldP_cds', 0))
#
# Rule('sliding_lldR_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldR', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'lldR', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldR', type = 'cds', prot = 1, free = 'False') + rna(name = 'lldR', type = 'cds', dna = None, prot = None) + dna(name = 'lldR', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldR_rbs', 0))
#
# Rule('sliding_lldR_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldR', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'lldD', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'rbs', prot = 1, free = 'False') + rna(name = 'lldD', type = 'rbs', dna = None, prot = None) + dna(name = 'lldR', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldR_cds', 0))
#
# Rule('sliding_lldD_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'lldD', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'cds', prot = 1, free = 'False') + rna(name = 'lldD', type = 'cds', dna = None, prot = None) + dna(name = 'lldD', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldD_rbs', 0))
#
# Rule('sliding_lldD_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'lldD', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'lldD', type = 'ter1', prot = 1, free = 'False') + rna(name = 'lldD', type = 'ter1', dna = None, prot = None) + dna(name = 'lldD', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_lldD_cds', 0))

# %%
for dna_part in architecture:
    Rule = ''

    if 'rbs' in dna_part: # docking rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'dr_{:s}\', cplx(name = \'Ribosome\', rna = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None) |\n' \
               '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1),\n' \
               '    Parameter(\'fwd_dr_{:s}\', 0), Parameter(\'rvs_dr_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
        
    elif 'ter' in dna_part: # falloff rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'fr_{:s}\', cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) >>\n' \
               '    cplx(name = \'Ribosome\', rna = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
               '    Parameter(\'fwd_fr_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('dr_fucP_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucP', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucP', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucP_rbs', 0), Parameter('rvs_dr_fucP_rbs', 0))
#
# Rule('dr_fucI_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucI', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucI', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucI_rbs', 0), Parameter('rvs_dr_fucI_rbs', 0))
#
# Rule('dr_fucK_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucK', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucK', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucK_rbs', 0), Parameter('rvs_dr_fucK_rbs', 0))
#
# Rule('dr_fucU_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucU', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucU_rbs', 0), Parameter('rvs_dr_fucU_rbs', 0))
#
# Rule('dr_fucR_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucR', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucR_rbs', 0), Parameter('rvs_dr_fucR_rbs', 0))
#
# Rule('fr_fucR_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'fucR', type = 'ter1', prot = None),
#     Parameter('fwd_fr_fucR_ter1', 0))
#
# Rule('dr_fucA_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucA', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucA_rbs', 0), Parameter('rvs_dr_fucA_rbs', 0))
#
# Rule('dr_fucO_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fucO', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fucO_rbs', 0), Parameter('rvs_dr_fucO_rbs', 0))
#
# Rule('fr_fucO_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'fucO', type = 'ter1', prot = None),
#     Parameter('fwd_fr_fucO_ter1', 0))
#
# Rule('dr_aldA_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'aldA', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_aldA_rbs', 0), Parameter('rvs_dr_aldA_rbs', 0))
#
# Rule('fr_aldA_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'aldA', type = 'ter1', prot = None),
#     Parameter('fwd_fr_aldA_ter1', 0))
#
# Rule('dr_lldP_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'lldP', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_lldP_rbs', 0), Parameter('rvs_dr_lldP_rbs', 0))
#
# Rule('dr_lldR_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'lldR', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldR', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_lldR_rbs', 0), Parameter('rvs_dr_lldR_rbs', 0))
#
# Rule('dr_lldD_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'lldD', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_lldD_rbs', 0), Parameter('rvs_dr_lldD_rbs', 0))
#
# Rule('fr_lldD_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'lldD', type = 'ter1', prot = None),
#     Parameter('fwd_fr_lldD_ter1', 0))

# %%
forward = False
for dna_part1, dna_part2 in zip(data.SOURCE, data.TARGET):
    name1 = dna_part1.split('-')[0]
    type1 = dna_part1.split('-')[1]
    name2 = dna_part2.split('-')[0]
    type2 = dna_part2.split('-')[1]

    if 'rbs' in type1:
        forward = True
        
    if forward:
        if 'cds' in type2:
            Rule = 'Rule(\'sr_{:s}\',\n'\
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + None + rna(name = \'{:s}\', type = \'{:s}\', prot = None) >>\n' \
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + prot(name = \'{:s}\', loc = \'cyt\', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
                   '    Parameter(\'fwd_sr_{:s}\', 0))' \
                   .format(dna_part1, name1, type1, name2, type2, name2, type2, name2, name2, type2, dna_part1)

        else: # just sliding
            Rule = 'Rule(\'sr_{:s}\',\n'\
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + rna(name = \'{:s}\', type = \'{:s}\', prot = None) >>\n' \
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
                   '    Parameter(\'fwd_sr_{:s}\', 0))' \
                   .format(dna_part1, name1, type1, name2, type2, name2, type2, name1, type1, dna_part1)
            
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('sr_fucP_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucP', type = 'rbs', prot = 1) + None + rna(name = 'fucP', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucP', type = 'cds', prot = 1) + prot(name = 'fucP', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucP', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucP_rbs', 0))
#
# Rule('sr_fucP_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucP', type = 'cds', prot = 1) + rna(name = 'fucI', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucI', type = 'rbs', prot = 1) + rna(name = 'fucP', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucP_cds', 0))
#
# Rule('sr_fucI_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucI', type = 'rbs', prot = 1) + None + rna(name = 'fucI', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucI', type = 'cds', prot = 1) + prot(name = 'fucI', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucI', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucI_rbs', 0))
#
# Rule('sr_fucI_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucI', type = 'cds', prot = 1) + rna(name = 'fucK', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucK', type = 'rbs', prot = 1) + rna(name = 'fucI', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucI_cds', 0))
#
# Rule('sr_fucK_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucK', type = 'rbs', prot = 1) + None + rna(name = 'fucK', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucK', type = 'cds', prot = 1) + prot(name = 'fucK', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucK', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucK_rbs', 0))
#
# Rule('sr_fucK_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucK', type = 'cds', prot = 1) + rna(name = 'fucU', type = 'pro1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'pro1', prot = 1) + rna(name = 'fucK', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucK_cds', 0))
#
# Rule('sr_fucU_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'pro1', prot = 1) + rna(name = 'fucU', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'rbs', prot = 1) + rna(name = 'fucU', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fucU_pro1', 0))
#
# Rule('sr_fucU_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'rbs', prot = 1) + None + rna(name = 'fucU', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'cds', prot = 1) + prot(name = 'fucU', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucU', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucU_rbs', 0))
#
# Rule('sr_fucU_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucU', type = 'cds', prot = 1) + rna(name = 'fucR', type = 'pro1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'pro1', prot = 1) + rna(name = 'fucU', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucU_cds', 0))
#
# Rule('sr_fucR_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'pro1', prot = 1) + rna(name = 'fucR', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'rbs', prot = 1) + rna(name = 'fucR', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fucR_pro1', 0))
#
# Rule('sr_fucR_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'rbs', prot = 1) + None + rna(name = 'fucR', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'cds', prot = 1) + prot(name = 'fucR', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucR', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucR_rbs', 0))
#
# Rule('sr_fucR_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'cds', prot = 1) + rna(name = 'fucR', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucR', type = 'ter1', prot = 1) + rna(name = 'fucR', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucR_cds', 0))
#
# Rule('sr_fucA_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'pro1', prot = 1) + rna(name = 'fucA', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'rbs', prot = 1) + rna(name = 'fucA', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fucA_pro1', 0))
#
# Rule('sr_fucA_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'rbs', prot = 1) + None + rna(name = 'fucA', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'cds', prot = 1) + prot(name = 'fucA', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucA', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucA_rbs', 0))
#
# Rule('sr_fucA_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucA', type = 'cds', prot = 1) + rna(name = 'fucO', type = 'pro1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'pro1', prot = 1) + rna(name = 'fucA', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucA_cds', 0))
#
# Rule('sr_fucO_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'pro1', prot = 1) + rna(name = 'fucO', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'rbs', prot = 1) + rna(name = 'fucO', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fucO_pro1', 0))
#
# Rule('sr_fucO_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'rbs', prot = 1) + None + rna(name = 'fucO', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'cds', prot = 1) + prot(name = 'fucO', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fucO', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucO_rbs', 0))
#
# Rule('sr_fucO_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'cds', prot = 1) + rna(name = 'fucO', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fucO', type = 'ter1', prot = 1) + rna(name = 'fucO', type = 'cds', prot = None),
#     Parameter('fwd_sr_fucO_cds', 0))
#
# Rule('sr_aldA_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'pro1', prot = 1) + rna(name = 'aldA', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'rbs', prot = 1) + rna(name = 'aldA', type = 'pro1', prot = None),
#     Parameter('fwd_sr_aldA_pro1', 0))
#
# Rule('sr_aldA_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'rbs', prot = 1) + None + rna(name = 'aldA', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'cds', prot = 1) + prot(name = 'aldA', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'aldA', type = 'cds', prot = None),
#     Parameter('fwd_sr_aldA_rbs', 0))
#
# Rule('sr_aldA_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'cds', prot = 1) + rna(name = 'aldA', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'aldA', type = 'ter1', prot = 1) + rna(name = 'aldA', type = 'cds', prot = None),
#     Parameter('fwd_sr_aldA_cds', 0))
#
# Rule('sr_lldP_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'pro1', prot = 1) + rna(name = 'lldP', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'rbs', prot = 1) + rna(name = 'lldP', type = 'pro1', prot = None),
#     Parameter('fwd_sr_lldP_pro1', 0))
#
# Rule('sr_lldP_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'rbs', prot = 1) + None + rna(name = 'lldP', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'cds', prot = 1) + prot(name = 'lldP', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'lldP', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldP_rbs', 0))
#
# Rule('sr_lldP_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldP', type = 'cds', prot = 1) + rna(name = 'lldR', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldR', type = 'rbs', prot = 1) + rna(name = 'lldP', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldP_cds', 0))
#
# Rule('sr_lldR_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldR', type = 'rbs', prot = 1) + None + rna(name = 'lldR', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldR', type = 'cds', prot = 1) + prot(name = 'lldR', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'lldR', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldR_rbs', 0))
#
# Rule('sr_lldR_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldR', type = 'cds', prot = 1) + rna(name = 'lldD', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'rbs', prot = 1) + rna(name = 'lldR', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldR_cds', 0))
#
# Rule('sr_lldD_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'rbs', prot = 1) + None + rna(name = 'lldD', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'cds', prot = 1) + prot(name = 'lldD', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'lldD', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldD_rbs', 0))
#
# Rule('sr_lldD_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'cds', prot = 1) + rna(name = 'lldD', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'lldD', type = 'ter1', prot = 1) + rna(name = 'lldD', type = 'cds', prot = None),
#     Parameter('fwd_sr_lldD_cds', 0))

# %%
Initials = []

c = list(zip(list(data.SOURCE), list(data.TARGET)))
c = [elt for sublist in c for elt in sublist]

for dna_part in list(dict.fromkeys(c).keys()):
    name = dna_part.split('-')[0]
    type = dna_part.split('-')[1]
    
    print('Initial(dna(name = \'{:s}\', type = \'{:s}\', prot = None, rna = None, up = None, dw = None), Parameter(\'t0_{:s}_{:s}_dna\', 1))'.format(name, type, name, type))
# Out:
# Initial(dna(name = 'fucP', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucP_pro1_dna', 1))
# Initial(dna(name = 'fucP', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucP_rbs_dna', 1))
# Initial(dna(name = 'fucP', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucP_cds_dna', 1))
# Initial(dna(name = 'fucI', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucI_rbs_dna', 1))
# Initial(dna(name = 'fucI', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucI_cds_dna', 1))
# Initial(dna(name = 'fucK', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucK_rbs_dna', 1))
# Initial(dna(name = 'fucK', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucK_cds_dna', 1))
# Initial(dna(name = 'fucU', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucU_pro1_dna', 1))
# Initial(dna(name = 'fucU', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucU_rbs_dna', 1))
# Initial(dna(name = 'fucU', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucU_cds_dna', 1))
# Initial(dna(name = 'fucR', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucR_pro1_dna', 1))
# Initial(dna(name = 'fucR', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucR_rbs_dna', 1))
# Initial(dna(name = 'fucR', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucR_cds_dna', 1))
# Initial(dna(name = 'fucR', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucR_ter1_dna', 1))
# Initial(dna(name = 'fucA', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucA_pro1_dna', 1))
# Initial(dna(name = 'fucA', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucA_rbs_dna', 1))
# Initial(dna(name = 'fucA', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucA_cds_dna', 1))
# Initial(dna(name = 'fucO', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucO_pro1_dna', 1))
# Initial(dna(name = 'fucO', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucO_rbs_dna', 1))
# Initial(dna(name = 'fucO', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucO_cds_dna', 1))
# Initial(dna(name = 'fucO', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fucO_ter1_dna', 1))
# Initial(dna(name = 'aldA', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_aldA_pro1_dna', 1))
# Initial(dna(name = 'aldA', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_aldA_rbs_dna', 1))
# Initial(dna(name = 'aldA', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_aldA_cds_dna', 1))
# Initial(dna(name = 'aldA', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_aldA_ter1_dna', 1))
# Initial(dna(name = 'lldP', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldP_pro1_dna', 1))
# Initial(dna(name = 'lldP', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldP_rbs_dna', 1))
# Initial(dna(name = 'lldP', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldP_cds_dna', 1))
# Initial(dna(name = 'lldR', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldR_rbs_dna', 1))
# Initial(dna(name = 'lldR', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldR_cds_dna', 1))
# Initial(dna(name = 'lldD', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldD_rbs_dna', 1))
# Initial(dna(name = 'lldD', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldD_cds_dna', 1))
# Initial(dna(name = 'lldD', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_lldD_ter1_dna', 1))
